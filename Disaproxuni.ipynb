# %% [markdown]
# <a href="https://colab.research.google.com/github/MaricelaMH/Simulacion-1/blob/main/Disaproxuni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def proxnorm(n):
    Lista = []
    for i in range(n):
        u=rnd.random()
        x=(((u)**0.135)-(1-u)**0.135)/0.1975
        Lista.append(x)
    return Lista

# %%
G=proxnorm(1000000)
#print(G)

# %%
mu=np.mean(G)
print(mu)
# Out:
# 0.001993335521615749

# %%
sigma2=np.var(G)
print(sigma2)
# Out:
# 1.0010066667535626

# %%
plt.hist(G,bins=100,color='lightblue')
# Out:
# (array([2.0000e+00, 1.0000e+00, 4.0000e+00, 7.0000e+00, 1.2000e+01,
#         1.7000e+01, 2.1000e+01, 3.4000e+01, 5.2000e+01, 5.0000e+01,
#         9.1000e+01, 1.1800e+02, 1.6100e+02, 2.3000e+02, 2.9900e+02,
#         3.9100e+02, 5.0100e+02, 6.2400e+02, 8.0000e+02, 9.4700e+02,
#         1.2330e+03, 1.5130e+03, 1.8710e+03, 2.2420e+03, 2.6750e+03,
#         3.2510e+03, 3.8000e+03, 4.5420e+03, 5.1690e+03, 6.0250e+03,
#         7.1580e+03, 8.2650e+03, 9.5080e+03, 1.0738e+04, 1.2010e+04,
#         1.3611e+04, 1.4989e+04, 1.6585e+04, 1.8331e+04, 2.0115e+04,
#         2.1710e+04, 2.3355e+04, 2.5047e+04, 2.6876e+04, 2.8171e+04,
#         2.9304e+04, 3.0598e+04, 3.1597e+04, 3.2329e+04, 3.3176e+04,
#         3.3194e+04, 3.3415e+04, 3.3680e+04, 3.2990e+04, 3.2653e+04,
#         3.1620e+04, 3.0722e+04, 2.9181e+04, 2.8123e+04, 2.6602e+04,
#         2.5070e+04, 2.3347e+04, 2.1687e+04, 2.0162e+04, 1.8204e+04,
#         1.6440e+04, 1.5082e+04, 1.3520e+04, 1.2050e+04, 1.0721e+04,
# ...

# %%
plt.plot(G,color='lightblue')

# %%
def cdf(G):
  n = len(G)
  x = np.sort(G)
  y = np.arange(0,n)/n
  return x,y

# %%
x,y = cdf(G)

# %%
plt.step(x,y)
plt.axhline(0.5,color="red")
plt.axvline(mu,color="green")
