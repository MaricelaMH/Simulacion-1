# %% [markdown]
# <a href="https://colab.research.google.com/github/MaricelaMH/Simulacion-1/blob/main/Metcomp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np


def generar_muestra(n):
    Lista = []

    for i in range(n):
        u = rnd.random()
        v=rnd.random()

        if 0 <= u <= 0.5:
            x = np.log(2 * v) / 2
        else:
            x = -np.log(2 * (1 - v)) / 2
        Lista.append(x)

    return Lista

# %%
# Ejemplo de uso
n = 1000000 # Número de muestras deseadas
G = generar_muestra(n)

# %%
plt.hist(G,bins=100,color='lightblue')
# Out:
# (array([1.00000e+00, 0.00000e+00, 2.00000e+00, 3.00000e+00, 0.00000e+00,
#         3.00000e+00, 1.00000e+00, 0.00000e+00, 1.00000e+00, 3.00000e+00,
#         4.00000e+00, 5.00000e+00, 5.00000e+00, 6.00000e+00, 2.00000e+00,
#         9.00000e+00, 1.70000e+01, 3.00000e+00, 1.30000e+01, 2.60000e+01,
#         3.00000e+01, 4.20000e+01, 6.40000e+01, 7.90000e+01, 9.40000e+01,
#         1.28000e+02, 1.56000e+02, 2.01000e+02, 2.63000e+02, 3.39000e+02,
#         4.24000e+02, 4.89000e+02, 6.85000e+02, 8.48000e+02, 1.12000e+03,
#         1.39700e+03, 1.90100e+03, 2.44500e+03, 3.08900e+03, 3.99400e+03,
#         5.15500e+03, 6.58800e+03, 8.54500e+03, 1.09760e+04, 1.44190e+04,
#         1.80400e+04, 2.33150e+04, 6.69960e+04, 1.42784e+05, 1.30252e+05,
#         1.26543e+05, 1.31259e+05, 1.43665e+05, 5.17130e+04, 2.27760e+04,
#         1.75400e+04, 1.36700e+04, 1.06250e+04, 8.37100e+03, 6.40200e+03,
#         5.00100e+03, 3.93800e+03, 3.00900e+03, 2.34900e+03, 1.80900e+03,
# ...

# %%
plt.plot(G,color='lightblue')

# %%
def cdf(muestras):
  n = len(muestras)
  x = np.sort(muestras)
  y = np.arange(0,n)/n
  return x,y

# %%
x,y = cdf(G)

# %%
mu=np.mean(G)

# %%
plt.step(x,y)
plt.axhline(0.5,color="red")
plt.axvline(mu,color="green")
