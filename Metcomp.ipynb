# %% [markdown]
# <a href="https://colab.research.google.com/github/MaricelaMH/Simulacion-1/blob/main/Metcomp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import math

def generar_muestra(n):
  Lista = []

  for i in range(n):
      u = rnd.random()
      v = rnd.random()
      if  u <= 0.5:
        x = (np.log(2 * v) )/ 2
      else:
        x = (-np.log((-2*v)+1)) / 2

      Lista.append(x)

  return Lista

# %%
# Ejemplo de uso
n = 100000# Número de muestras deseadas
G = generar_muestra(n)
# Out:
# <ipython-input-54-428ed44ff6d3>:13: RuntimeWarning: invalid value encountered in log
#   x = (-np.log((-2*v)+1)) / 2

# %%
plt.hist(G,bins=100,color='lightblue')
# Out:
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 2.0000e+00, 0.0000e+00, 1.0000e+00, 3.0000e+00,
#         1.0000e+00, 3.0000e+00, 0.0000e+00, 4.0000e+00, 1.0000e+00,
#         5.0000e+00, 2.0000e+00, 9.0000e+00, 9.0000e+00, 1.1000e+01,
#         1.3000e+01, 1.0000e+01, 2.3000e+01, 2.8000e+01, 3.0000e+01,
#         3.7000e+01, 4.8000e+01, 6.3000e+01, 7.2000e+01, 8.3000e+01,
#         9.2000e+01, 1.1200e+02, 1.3800e+02, 2.0300e+02, 2.4800e+02,
#         2.9200e+02, 3.7800e+02, 4.2900e+02, 5.2000e+02, 6.6900e+02,
#         8.5900e+02, 9.6900e+02, 1.2760e+03, 1.4480e+03, 1.9040e+03,
#         2.1900e+03, 2.7600e+03, 3.5420e+03, 4.2820e+03, 7.9500e+03,
#         1.0510e+04, 1.1348e+04, 1.0190e+04, 2.2600e+03, 1.8430e+03,
#         1.5290e+03, 1.1610e+03, 9.5200e+02, 7.9000e+02, 6.3200e+02,
#         5.3900e+02, 4.4400e+02, 3.3000e+02, 2.8300e+02, 2.1600e+02,
#         1.9500e+02, 1.5100e+02, 1.1700e+02, 8.4000e+01, 7.7000e+01,
#         5.7000e+01, 4.6000e+01, 5.1000e+01, 3.5000e+01, 2.7000e+01,
#         2.4000e+01, 1.8000e+01, 8.0000e+00, 1.2000e+01, 9.0000e+00,
#         1.1000e+01, 4.0000e+00, 7.0000e+00, 3.0000e+00, 3.0000e+00,
#         3.0000e+00, 5.0000e+00, 1.0000e+00, 2.0000e+00, 2.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([-5.68489645, -5.58052054, -5.47614463, -5.37176872, -5.26739281,
#         -5.1630169 , -5.05864099, -4.95426508, -4.84988917, -4.74551326,
#         -4.64113735, -4.53676144, -4.43238553, -4.32800962, -4.22363371,
#         -4.1192578 , -4.01488189, -3.91050598, -3.80613007, -3.70175416,
#         -3.59737825, -3.49300234, -3.38862643, -3.28425053, -3.17987462,
#         -3.07549871, -2.9711228 , -2.86674689, -2.76237098, -2.65799507,
#         -2.55361916, -2.44924325, -2.34486734, -2.24049143, -2.13611552,
#         -2.03173961, -1.9273637 , -1.82298779, -1.71861188, -1.61423597,
#         -1.50986006, -1.40548415, -1.30110824, -1.19673233, -1.09235642,
#         -0.98798051, -0.8836046 , -0.77922869, -0.67485278, -0.57047687,
#         -0.46610096, -0.36172505, -0.25734914, -0.15297323, -0.04859732,
#          0.05577859,  0.1601545 ,  0.26453041,  0.36890632,  0.47328222,
#          0.57765813,  0.68203404,  0.78640995,  0.89078586,  0.99516177,
#          1.09953768,  1.20391359,  1.3082895 ,  1.41266541,  1.51704132,
#          1.62141723,  1.72579314,  1.83016905,  1.93454496,  2.03892087,
#          2.14329678,  2.24767269,  2.3520486 ,  2.45642451,  2.56080042,
#          2.66517633,  2.76955224,  2.87392815,  2.97830406,  3.08267997,
#          3.18705588,  3.29143179,  3.3958077 ,  3.50018361,  3.60455952,
#          3.70893543,  3.81331134,  3.91768725,  4.02206316,  4.12643906,
#          4.23081497,  4.33519088,  4.43956679,  4.5439427 ,  4.64831861,
#          4.75269452]),
#  <BarContainer object of 100 artists>)

# %%
plt.plot(G,color='lightblue')

# %%
def cdf(muestras):
  n = len(muestras)
  x = np.sort(muestras)
  y = np.arange(0,n)/n
  return x,y

# %%
x,y = cdf(G)

# %%
mu=np.mean(G)

# %%
plt.step(x,y)
plt.axhline(0.5,color="red")
plt.axvline(mu,color="green")
