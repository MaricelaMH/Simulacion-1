# %% [markdown]
# <a href="https://colab.research.google.com/github/MaricelaMH/Simulacion-1/blob/main/Media_Muestral_MC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Implementamos las librerias necesarias
import numpy as np
import random as rnd
import matplotlib.pyplot as plt

# %%
# Definimos nuestra función g(x)
def g(x):
    return np.sqrt(np.arctan(x))

# %%
# Implementamos el método de Monte Carlo
def monte_carlo_integral(a, b, n):
    # Generar una secuencia {Ui}
    U = np.random.uniform(a,b,n)

    # Calculamos Xi = a + Ui * (b - a)
    X = a + U * (b - a)

    # Calculamos g(X)
    g_X = g(X)

    # Calculamos la media muestral θ1
    theta_1 = (b - a) * np.mean(g_X)

    return theta_1

# %%
# Calcular la estimación de la integral
integral_est = monte_carlo_integral(0,1,10000)
print(f"Estimación de la integral: {integral_est}")
# Out:
# Estimación de la integral: 0.6294343554732091

# %%
num_est = 1000  # Número de estimaciones para el histograma

# Generar múltiples estimaciones de la integral
integral_est2 = [monte_carlo_integral(a, b, n) for _ in range(num_est)]

# Graficar el histograma de las estimaciones de la integral
plt.hist(integral_est2, bins=30, edgecolor='k', alpha=0.7)
plt.title('Histograma de la Aproximación de la Integral usando el Método de Monte Carlo')
plt.xlabel('Estimación de la Integral')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
