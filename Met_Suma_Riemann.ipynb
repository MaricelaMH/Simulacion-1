# %% [markdown]
# <a href="https://colab.research.google.com/github/MaricelaMH/Simulacion-1/blob/main/Met_Suma_Riemann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %%
# Definimos la función g(x)
def g(x):
     return np.sqrt(np.arctan(x))

# %%
# Definimos una funcion para calcular la suma de Riemann
def suma_riemann(a, b, n):
    # Calculamos la longitud de cada subintervalo
    delta_x = (b - a) / n

    # Calculamos los puntos medios de cada subintervalo
    puntos_medios = np.linspace(a + delta_x / 2, b - delta_x / 2, n)

    # Evaluamos la función g(x) en los puntos medios
    valores_funcion = g(puntos_medios)

    # Calculamos la suma de Riemann
    suma = np.sum(valores_funcion * delta_x)

    return suma, puntos_medios, valores_funcion, delta_x

# %%
# Calculamos la suma de Riemann y obtenemos los puntos de evaluación
suma, puntos_medios, valores_funcion, delta_x = suma_riemann(0, 1, 50)
print("Aproximación de la integral:", suma)
# Out:
# Aproximación de la integral: 0.629990862661826

# %%
# Graficamos la función g(x)
x = np.linspace(0, 1, 50)
y = g(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label=r'$g(x) = \sqrt{\arctan(x)}$', color='blue')
plt.bar(puntos_medios, valores_funcion, width=delta_x, alpha=0.3, align='center', edgecolor='black', label='Sumas de Riemann')

plt.xlabel('x')
plt.ylabel('g(x)')
plt.title(r'Método de Sumas de Riemann')
plt.legend()
plt.grid(True)
plt.show()
